# %% [markdown]
# <a href="https://colab.research.google.com/github/sripathiamulya15/2025-26-4103-S.Amulya-AI-B-DS/blob/main/dictionaryoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a dictionary
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
    }
print("Original dictionary:", d)
# Out:
# Original dictionary: {'name': 'Amulya', 'age': 20, 'course': 'BTech'}

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Accessing values
print("Name:", d["name"])
print("Age:", d.get("age"))
# Out:
# Name: Amulya
# Age: 20

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Adding a new key-value pair
d["college"] = "XYZ University"
print("After adding:", d)
# Out:
# After adding: {'name': 'Amulya', 'age': 20, 'course': 'BTech', 'college': 'XYZ University'}

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Updating value
d["age"] = 21
print("After updating:", d)
# Out:
# After updating: {'name': 'Amulya', 'age': 21, 'course': 'BTech'}

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Removing elements
d.pop("course")
print("After pop:", d)
removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)
# Out:
# After pop: {'name': 'Amulya', 'age': 20}
# After popitem: {'name': 'Amulya'}
# Removed item: ('age', 20)

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())
# Out:
# Keys: dict_keys(['name', 'age', 'course'])
# Values: dict_values(['Amulya', 20, 'BTech'])
# Items: dict_items([('name', 'Amulya'), ('age', 20), ('course', 'BTech')])

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Length
print("Length of dictionary:", len(d))
# Out:
# Length of dictionary: 3

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Looping through dictionary
print("Looping through keys:")
for key in d:
    print(key, ":", d[key])
print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)
# Out:
# Looping through keys:
# name : Amulya
# age : 20
# course : BTech
# Looping through key-value pairs:
# name -> Amulya
# age -> 20
# course -> BTech

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Updating using update()
d.update({"city": "Hyderabad", "age": 22})
print("After update():", d)
# Out:
# After update(): {'name': 'Amulya', 'age': 22, 'course': 'BTech', 'city': 'Hyderabad'}

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Nested dictionary
student = {
    "id": 1,
    "info": {
        "name": "Amit",
        "marks": 90
    }
}
print("Nested dictionary value:", student["info"]["marks"])
# Out:
# Nested dictionary value: 90

# %%
d = {
    "name": "Amulya",
    "age": 20,
    "course": "BTech"
}
# Clearing dictionary
d.clear()
print("After clear:", d)
# Out:
# After clear: {}
