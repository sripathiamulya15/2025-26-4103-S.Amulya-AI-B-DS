# %% [markdown]
# <a href="https://colab.research.google.com/github/sripathiamulya15/2025-26-4103-S.Amulya-AI-B-DS/blob/main/searchingtechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***DATE : 10/2/2026***

# %% [markdown]
# # *SEARCHING ALGORITHMS*

# %%
#LINEAR SEARCH
n=int(input("Enter number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element{i+1}:")))
key=int(input("Enter element to be searched:"))
found=False
for i in range(n):
  if arr[i]==key:
    print(f"Element found at position {i+1}")
    found=True
    break
if not found:
  print("Element not found")
# Out:
# Enter number of elements:5
# Enter element1:6
# Enter element2:7
# Enter element3:3
# Enter element4:9
# Enter element5:2
# Enter element to be searched:7
# Element found at position 2

# %%
#BINARY SEARCH
n=int(input("Enter number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element{i+1}:")))
arr.sort()
print("\n Sorted list:",arr)
key=int(input("Enter element to be searched:"))
low=0
high=n-1
found=False
while low<=high:
  mid=(low+high)//2
  if arr[mid]==key:
    print(f"Element found at position {mid+1}")
    found=True
    break
  elif arr[mid]<key:
    low=mid+1
  else:
    high=mid-1
if not found:
  print("Element not found")
# Out:
# Enter number of elements:5
# Enter element1:6
# Enter element2:4
# Enter element3:3
# Enter element4:8
# Enter element5:2
#
#  Sorted list: [2, 3, 4, 6, 8]
# Enter element to be searched:4
# Element found at position 3
