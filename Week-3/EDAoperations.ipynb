# %% [markdown]
# <a href="https://colab.research.google.com/github/sripathiamulya15/2025-26-4103-S.Amulya-AI-B-DS/blob/main/Week-3/EDAoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QUESTION 13
# DATE : 17/02/26

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=[10,12,15,18,20,22,25,30,35,40]
df=pd.DataFrame(data,columns=['values'])
print("Dataset:")
print(df)
print("\nSummary statistics:")
print(df.describe())
print("\nVariance:",np.var(data))
print("\nStandard deviation:",np.std(data))
plt.hist(data)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Data Distribution')
plt.show()
mean_value=np.mean(data)
median_value=np.median(data)
mode_value = df['values'].mode()
print("\nInference:")
print("Mean:",mean_value)
print("Median:",median_value)
if len(mode_value) == 1:
    print("Mode:", mode_value[0])
else:
    print("Mode:", list(mode_value))
if mean_value>median_value:
    print("The distribution is positively skewed.")
elif mean_value<median_value:
    print("The distribution is negatively skewed.")
else:
    print("The distribution is symmetric.")
# Out:
# Dataset:
#    values
# 0      10
# 1      12
# 2      15
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Summary statistics:
#           values
# count  10.000000
# mean   22.700000
# std     9.855061
# min    10.000000
# 25%    15.750000
# 50%    21.000000
# 75%    28.750000
# max    40.000000
#
# Variance: 87.41
#
# Standard deviation: 9.34933152690608
# Inference:
# Mean: 22.7
# Median: 21.0
# Mode: [10, 12, 15, 18, 20, 22, 25, 30, 35, 40]
# The distribution is positively skewed.
